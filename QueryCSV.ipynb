# %%
import pandas as pd

# %%
raw = pd.read_csv('/home/chenjie/Desktop/Math564Project/final_table.csv')

# %%
raw.head()
# Out:
#    Season TEAM  win  loss    pct  home   away   div   conf    ppg  ...   \
# 0    2014   SA   62    20  0.756  32-9  30-11  12-4  38-14  105.4  ...
# 1    2014   SA   62    20  0.756  32-9  30-11  12-4  38-14  105.4  ...
# 2    2014   SA   62    20  0.756  32-9  30-11  12-4  38-14  105.4  ...
# 3    2014   SA   62    20  0.756  32-9  30-11  12-4  38-14  105.4  ...
# 4    2014   SA   62    20  0.756  32-9  30-11  12-4  38-14  105.4  ...
#
#       TS   AST    TO   USG  ORR   DRR  REBR    PER     VA   EWA
# 0  0.535  15.4  11.2  23.5  8.6  28.3  18.8  21.40  318.8  10.6
# 1  0.590  25.7  12.2  24.2  2.3  12.0   7.3  20.06  221.2   7.4
# 2  0.602  14.6   8.8  17.0  4.6  18.9  12.1  19.43  256.3   8.5
# 3  0.555  24.9   9.7  25.9  1.0   7.5   4.4  19.00  238.5   7.9
# 4  0.588  16.3   6.9  21.2  2.6   9.6   6.2  18.80  177.7   5.9
#
# [5 rows x 26 columns]

# %%
list(raw)
# Out:
# ['Season',
#  'TEAM',
#  'win',
#  'loss',
#  'pct',
#  'home',
#  'away',
#  'div',
#  'conf',
#  'ppg',
#  'opp_ppg',
#  'diff',
#  'RK',
#  'PLAYER',
#  'GP',
#  'MPG',
#  'TS',
#  'AST',
#  'TO',
#  'USG',
#  'ORR',
#  'DRR',
#  'REBR',
#  'PER',
#  'VA',
#  'EWA']

# %%
raw['MPG_Times_PER'] = raw['MPG']*raw['PER']

# %%
list(raw)
# Out:
# ['Season',
#  'TEAM',
#  'win',
#  'loss',
#  'pct',
#  'home',
#  'away',
#  'div',
#  'conf',
#  'ppg',
#  'opp_ppg',
#  'diff',
#  'RK',
#  'PLAYER',
#  'GP',
#  'MPG',
#  'TS',
#  'AST',
#  'TO',
#  'USG',
#  'ORR',
#  'DRR',
#  'REBR',
#  'PER',
#  'VA',
#  'EWA',
#  'MPG_Times_PER']

# %%
raw.to_csv('table.csv')

# %%
raw.groupby(['Season','TEAM'])['MPG'].nlargest(8)
# Out:
# Season  TEAM
# 2014    ATL   200     33.9
#               194     33.5
#               193     33.0
#               195     32.2
#               199     32.1
#               197     24.1
#               201     20.4
#               198     19.4
#         BKN   170     32.6
#               168     32.2
#               165     31.4
#               169     28.0
#               171     26.0
#               175     24.2
#               177     22.7
#               167     22.2
#         BOS   308     34.2
#               303     33.3
#               309     30.9
#               302     27.6
#               305     27.6
#               307     25.0
#               312     24.4
#               310     23.4
#         CHI   137     38.7
#               131     35.3
#               135     35.1
#               138     31.5
#               140     29.0
#               133     28.7
#                       ...
# 2018    SAC   1862    27.8
#               1860    27.0
#               1856    25.6
# ...

# %%
raw_sorted
# Out:
# Season  TEAM
# 2014    ATL   200     33.9
#               194     33.5
#               193     33.0
#               195     32.2
#               199     32.1
#               197     24.1
#               201     20.4
#               198     19.4
#         BKN   170     32.6
#               168     32.2
#               165     31.4
#               169     28.0
#               171     26.0
#               175     24.2
#               177     22.7
#               167     22.2
#         BOS   308     34.2
#               303     33.3
#               309     30.9
#               302     27.6
#               305     27.6
#               307     25.0
#               312     24.4
#               310     23.4
#         CHI   137     38.7
#               131     35.3
#               135     35.1
#               138     31.5
#               140     29.0
#               133     28.7
#                       ...
# 2018    SAC   1862    27.8
#               1860    27.0
#               1856    25.6
# ...
